# %%
cd /root/hardware_rounding_error_predictor
# --- pdf parser + symlink literature into /workspace so extract_pdf_text finds it
apt-get install -y poppler-utils
mkdir -p /workspace
ln -sfn /root/hardware_rounding_error_predictor/literature /workspace/literature

# --- caches on /root (not the flaky /workspace mount from previous pods) --------
export HF_HOME=/root/hf_cache
export MUFU_CACHE_DIR=/root/mufu_cache
mkdir -p /root/hf_cache /root/mufu_cache
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (24.02.0-1ubuntu9.8).
# 0 upgraded, 0 newly installed, 0 to remove and 50 not upgraded.

# %%
# --- build catalog for the 4 demo seq lengths -----------------------------------
python3 build_catalog.py --seq-lens 100 250 1000 4000 --no-verify 2>&1 | tee /root/catalog_build.log
# Out:
# M grid restricted to 4 specified seq lengths: [100, 250, 1000, 4000]
#
# === down_proj (N=2560, K=9728) ===
#   [ 1/ 4] M=  100 N= 2560 K= 9728 /venv/main/lib/python3.12/site-packages/torch/profiler/profiler.py:224: UserWarning: Warning: Profiler clears events at the end of each cycle.Only events from the current cycle will be reported.To keep events across cycles, set acc_events=True.
#   _warn_once(
#   recipe=split_k_workspace_outtype    split_k=5  verify=skipped               kernel=ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_stages_64x3_tn
#   [ 2/ 4] M=  250 N= 2560 K= 9728   recipe=split_k_cutlass_bf16_out     split_k=2  verify=skipped               kernel=ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_stages_64x3_tn
#   [ 3/ 4] M= 1000 N= 2560 K= 9728   recipe=split_k_cutlass_bf16_out     split_k=4  verify=skipped               kernel=ampere_bf16_s16816gemm_bf16_256x128_ldg8_f2f_stages_64x3_tn
#   [ 4/ 4] M= 4000 N= 2560 K= 9728   recipe=single_walk                  split_k=1  verify=skipped               kernel=ampere_bf16_s16816gemm_bf16_256x128_ldg8_f2f_stages_64x3_tn
#   4 region(s) in this lane
#
# === gate_up_proj (N=9728, K=2560) ===
#   [ 1/ 4] M=  100 N= 9728 K= 2560   recipe=single_walk                  split_k=1  verify=skipped               kernel=ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_stages_64x3_tn
#   [ 2/ 4] M=  250 N= 9728 K= 2560   recipe=single_walk                  split_k=1  verify=skipped               kernel=ampere_bf16_s16816gemm_bf16_256x128_ldg8_f2f_stages_64x3_tn
#   [ 3/ 4] M= 1000 N= 9728 K= 2560   recipe=single_walk                  split_k=1  verify=skipped               kernel=ampere_bf16_s16816gemm_bf16_256x128_ldg8_f2f_stages_64x3_tn
#   [ 4/ 4] M= 4000 N= 9728 K= 2560   recipe=single_walk                  split_k=1  verify=skipped               kernel=ampere_bf16_s16816gemm_bf16_256x128_ldg8_f2f_stages_64x3_tn
#   2 region(s) in this lane
#
# Wrote cublas_catalog.json
#   6 regions total, 0 verified bit-exact, 0 mismatches

# %%
# --- demo script --------------------------------------------------------------
cat > /root/demo.sh << 'EOF'
#!/bin/bash
cd /root/hardware_rounding_error_predictor
export HF_HOME=/root/hf_cache MUFU_CACHE_DIR=/root/mufu_cache
for SEQ in 100 250 1000 4000; do
    echo "================ seq=$SEQ ================"
    python3 ffn_chain_test.py all $SEQ
    echo "---- cuBLAS mode ----"
    EMULATOR_TARGET=cublas python3 ffn_chain_test.py compare $SEQ
done
EOF

# --- auto-detect SKU for the log filename ---------------------------------------
SKU=$(nvidia-smi --query-gpu=name --format=csv,noheader | head -1 | tr -d ' ')
echo "Logging demo to /root/ffn_demo_${SKU}.log"

bash /root/demo.sh 2>&1 | tee /root/ffn_demo_${SKU}.log
# Out:
# Logging demo to /root/ffn_demo_NVIDIAA100-SXM4-40GB.log
# ================ seq=100 ================
# Sequence length override: 100
# Data dir: ffn_chain_data/seq100
# ================================================================================
# PHASE 1: INSTRUMENTED MODEL FORWARD PASS
# ================================================================================
#
# Loading Qwen/Qwen3-4B...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|██████████| 398/398 [00:02<00:00, 142.80it/s]
# Loaded. 36 layers, targeting layer 20.
#
# ARCHITECTURE INSPECTION
# ------------------------------------------------------------
#   model.config.hidden_size:       2560
#   model.config.intermediate_size:  9728
#   model.config.hidden_act:         silu
#   model.config.rms_norm_eps:       1e-06
#   LayerNorm type:  Qwen3RMSNorm
#   MLP type:        Qwen3MLP
#   act_fn type:     SiLUActivation
#   gate_proj:       torch.Size([9728, 2560])  bias=False
#   up_proj:         torch.Size([9728, 2560])  bias=False
#   down_proj:       torch.Size([2560, 9728])  bias=False
#   ln weight shape: torch.Size([2560])
#
# TOKENIZATION
# ------------------------------------------------------------
#   Using PDF (pdftotext): /workspace/literature/2403.00232v1.pdf
#   Sequence length: 100 tokens
#
# INSTRUMENTED FORWARD PASS
# ------------------------------------------------------------
#   Running model forward pass... done.
#   ffn_residual              [100, 2560]  dtype=torch.bfloat16  range=[-1912.0000, 6912.0000]
#   rms_out                   [100, 2560]  dtype=torch.bfloat16  range=[-16.7500, 7.5938]
#   gate_out                  [100, 9728]  dtype=torch.bfloat16  range=[-6.5000, 7.6562]
#   up_out                    [100, 9728]  dtype=torch.bfloat16  range=[-5.7188, 6.4375]
#   down_input                [100, 9728]  dtype=torch.bfloat16  range=[-10.8125, 13.3125]
#   down_out                  [100, 2560]  dtype=torch.bfloat16  range=[-4.4375, 6.4062]
#
# ARCHITECTURE VERIFICATION
# ------------------------------------------------------------
#   SiLU(gate_out) * up_out == down_proj input?
#     0/972800 BF16 diffs  *** CONFIRMED: act_fn is SiLU, no hidden casts or fused kernels ***
#   down_proj(captured_input) == captured_output?
#     0 diffs  *** CONFIRMED: down_proj is a plain linear, no hidden ops ***
#
# ELEMENT-WISE PRECISION VALIDATION
# ------------------------------------------------------------
#   SiLU GPU torch vs CPU torch:    0/972800 BF16 diffs
#   SiLU GPU torch vs CPU numpy:    0/972800 BF16 diffs
#   SiLU CPU torch vs CPU numpy:    0/972800 BF16 diffs
#   *** All three agree at BF16. Element-wise is safe. ***
#
# RMSNorm FP32 INTERMEDIATE CAPTURE
# ------------------------------------------------------------
#   gpu_sumsq:      [100, 1]  range=[2915.1816, 51676752.0000]
#   gpu_variance:   [100, 1]  range=[1.138743, 20186.232422]
#   gpu_rsqrt:      [100, 1]  range=[0.007038, 0.937102]
#
# SAVING DATA
# ------------------------------------------------------------
#   ffn_chain_data/seq100/model_ffn_residual.bin
#   ffn_chain_data/seq100/model_rms_out.bin
#   ffn_chain_data/seq100/model_gate_out.bin
#   ffn_chain_data/seq100/model_up_out.bin
#   ffn_chain_data/seq100/model_down_input.bin
#   ffn_chain_data/seq100/model_down_out.bin
#   ffn_chain_data/seq100/model_ffn_block_out.bin
#   ffn_chain_data/seq100/model_silu_gate.bin
#   ffn_chain_data/seq100/gpu_rms_sumsq.bin       [100, 1]
#   ffn_chain_data/seq100/gpu_rms_variance.bin     [100, 1]
#   ffn_chain_data/seq100/gpu_rms_rsqrt.bin        [100, 1]
#   ffn_chain_data/seq100/gpu_rms_normed_f32.bin   [100, 2560]
#   ffn_chain_data/seq100/gpu_rms_normed_bf16.bin  [100, 2560]
#   ffn_chain_data/seq100/ln_weight.bin
#   ffn_chain_data/seq100/gate_w.bin  [2560, 9728]
#   ffn_chain_data/seq100/up_w.bin    [2560, 9728]
#   ffn_chain_data/seq100/down_w.bin  [9728, 2560]
#   ffn_chain_data/seq100/meta.json
#
# Phase 1 complete. 8 tensors captured from layer 20.
# Next: python3 ffn_chain_test.py cutlass
#
# ================================================================================
#
# ================================================================================
# PHASE 2: CUTLASS MATMULS + CHAINED GROUND TRUTH
# ================================================================================
#
#   gate_proj: [100,2560]x[2560,9728]... OK
#   gate_proj (FP32): [100,2560]x[2560,9728]... OK
#   up_proj: [100,2560]x[2560,9728]... OK
#   up_proj (FP32): [100,2560]x[2560,9728]... OK
#   SiLU(gate)*up... OK
#   down_proj: [100,9728]x[9728,2560]... OK
#   down_proj (FP32): [100,9728]x[9728,2560]... OK
#   residual add... OK
#
# Phase 2 complete. CUTLASS chain intermediates saved.
# Next: python3 ffn_chain_test.py compare
#
# ================================================================================
#
# ================================================================================
# PHASE 3: CPU EMULATOR + THREE-WAY DIAGNOSTIC
# ================================================================================
#
# Layer 20, seq_len=100, hidden=2560, ffn=9728
# Activation: silu, eps: 1e-06
# Estimated CPU emulator time: ~3736s for 3 matmuls (7471M MAC ops)
#
# MUFU.RSQ: loaded cached tables for A100
# MUFU.EX2: loaded full table for A100 (4.3GB)
# MUFU.RCP: loaded cached table for A100
# GPU detected: A100
# Emulator: A100 bf16→fp32: NFMA=8, neab=1, window=(2,23,1)=26b, round=trunc, denorm=True, MMA=(16, 8, 16), c_order=early, interleaved=False
#
# EMULATOR CHAIN
# ------------------------------------------------------------
#   [1/7] RMSNorm... done (0.8s)
#   [2/7] gate_proj [100,2560]x[2560,9728]... done (4.8s)
#   [3/7] up_proj [100,2560]x[2560,9728]... done (4.5s)
#   [4/7] SiLU... done (0.0s)
#   [5/7] SiLU*up... done (0.1s)
#   [6/7] down_proj [100,9728]x[9728,2560]... done (5.0s)
#   [7/7] residual add... done (0.1s)
#
#   Total: 15.3s
#
#   Saving emulator intermediates...
#   Saved 7 BF16 + 8 raw FP32 tensors to ffn_chain_data/seq100/emu_*.bin
#
# ================================================================================
# THREE-WAY DIAGNOSTIC (every intermediate)
# ================================================================================
#
#   Stage                    Emu vs CUT     Emu vs Model     CUT vs Model
#   ---------------------------------------------------------------------
#   RMSNorm out              N/A            0/256000 ***       N/A
#   gate_proj out          0/972800 ***     0/972800 ***     0/972800 ***
#   up_proj out            0/972800 ***     0/972800 ***     0/972800 ***
#   SiLU(gate)             0/972800 ***     0/972800 ***     0/972800 ***
#   SiLU*up                0/972800 ***     0/972800 ***     0/972800 ***
#   down_proj out          0/256000 *** 100860/256000 (39.40%) 100860/256000 (39.40%)
#   FFN block out          0/256000 *** 45130/256000 (17.63%) 45130/256000 (17.63%)
#
# ================================================================================
# RMSNorm FP32 INTERMEDIATE DIAGNOSTIC
# ================================================================================
#
#   Stage                    FP32 diffs       BF16 diffs    rows affected
#   ----------------------------------------------------------------------
#   sum_of_squares                0/100            0/100            0/100
#   variance                      0/100            0/100            0/100
#   rsqrt                         0/100            0/100            0/100
#   normed_f32                 0/256000         0/256000            0/100
#   normed_bf16                0/256000         0/256000            0/100
#
# ================================================================================
# FP32 RAW ACCUMULATOR DIAGNOSTIC (before BF16 epilogue)
# ================================================================================
#
#   Stage                FP32 diffs   Hidden by BF16   BF16 diffs
#   --------------------------------------------------------------
#   gate_proj              0/972800                0            0
#   up_proj                0/972800                0            0
#   down_proj              0/256000                0            0
#
# ================================================================================
# ALL EMULATOR vs CUTLASS COMPARISONS: 0 DIFFS
#   4,403,200 total elements checked across 6 stages
#
# The CPU emulator predicts every BF16 bit of a full FFN block
# at layer 20 of Qwen/Qwen3-4B on 100 real tokens,
# targeting the cutlass kernel family.
# ---- cuBLAS mode ----
# Sequence length override: 100
# Data dir: ffn_chain_data/seq100
# ================================================================================
# PHASE 3: CPU EMULATOR + THREE-WAY DIAGNOSTIC
# ================================================================================
#
# Layer 20, seq_len=100, hidden=2560, ffn=9728
# Activation: silu, eps: 1e-06
# Estimated CPU emulator time: ~3736s for 3 matmuls (7471M MAC ops)
#
# MUFU.RSQ: loaded cached tables for A100
# MUFU.EX2: loaded full table for A100 (4.3GB)
# MUFU.RCP: loaded cached table for A100
# GPU detected: A100
# Emulator: A100 bf16→fp32: NFMA=8, neab=1, window=(2,23,1)=26b, round=trunc, denorm=True, MMA=(16, 8, 16), c_order=early, interleaved=False
#
# EMULATOR CHAIN
# ------------------------------------------------------------
#   [1/7] RMSNorm... done (0.5s)
#   [2/7] gate_proj [100,2560]x[2560,9728]...   [catalog mode] loaded 6 regions across 2 lanes
# done (5.0s)
#   [3/7] up_proj [100,2560]x[2560,9728]... done (4.7s)
#   [4/7] SiLU... done (0.2s)
#   [5/7] SiLU*up... done (0.1s)
#   [6/7] down_proj [100,9728]x[9728,2560]... done (4.8s)
#   [7/7] residual add... done (0.0s)
#
#   Total: 15.2s
#
#   Saving emulator intermediates...
#   Saved 7 BF16 + 8 raw FP32 tensors to ffn_chain_data/seq100/emu_*.bin
#
# ================================================================================
# THREE-WAY DIAGNOSTIC (every intermediate)
# ================================================================================
#
#   Stage                    Emu vs CUT     Emu vs Model     CUT vs Model
#   ---------------------------------------------------------------------
#   RMSNorm out              N/A            0/256000 ***       N/A
#   gate_proj out          0/972800 ***     0/972800 ***     0/972800 ***
#   up_proj out            0/972800 ***     0/972800 ***     0/972800 ***
#   SiLU(gate)             0/972800 ***     0/972800 ***     0/972800 ***
#   SiLU*up                0/972800 ***     0/972800 ***     0/972800 ***
#   down_proj out      100860/256000 (39.40%)     0/256000 *** 100860/256000 (39.40%)
#   FFN block out      45130/256000 (17.63%)     0/256000 *** 45130/256000 (17.63%)
#
# ================================================================================
# RMSNorm FP32 INTERMEDIATE DIAGNOSTIC
# ================================================================================
#
#   Stage                    FP32 diffs       BF16 diffs    rows affected
#   ----------------------------------------------------------------------
#   sum_of_squares                0/100            0/100            0/100
#   variance                      0/100            0/100            0/100
#   rsqrt                         0/100            0/100            0/100
#   normed_f32                 0/256000         0/256000            0/100
#   normed_bf16                0/256000         0/256000            0/100
#
# ================================================================================
# FP32 RAW ACCUMULATOR DIAGNOSTIC (before BF16 epilogue)
# ================================================================================
#
#   Skipped: this diagnostic compares the emulator's raw FP32 output
#   against CUTLASS's FP32 accumulator. In cuBLAS target mode, all
#   recipes BF16-round their output (because cuBLAS rounds to BF16 at
#   partition boundaries), so the emulator's 'FP32' output is BF16
#   precision stored in an FP32 container.
#
# ================================================================================
#
# ================================================================================
# ALL EMULATOR vs MODEL COMPARISONS: 0 DIFFS
#   4,659,200 total elements checked across 7 stages
#
# The CPU emulator predicts every BF16 bit of a full FFN block
# at layer 20 of Qwen/Qwen3-4B on 100 real tokens,
# targeting the model kernel family.
# ================ seq=250 ================
# Sequence length override: 250
# Data dir: ffn_chain_data/seq250
# ================================================================================
# PHASE 1: INSTRUMENTED MODEL FORWARD PASS
# ================================================================================
#
# Loading Qwen/Qwen3-4B...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|██████████| 398/398 [00:03<00:00, 129.22it/s]
# Loaded. 36 layers, targeting layer 20.
#
# ARCHITECTURE INSPECTION
# ------------------------------------------------------------
#   model.config.hidden_size:       2560
#   model.config.intermediate_size:  9728
#   model.config.hidden_act:         silu
#   model.config.rms_norm_eps:       1e-06
#   LayerNorm type:  Qwen3RMSNorm
#   MLP type:        Qwen3MLP
#   act_fn type:     SiLUActivation
#   gate_proj:       torch.Size([9728, 2560])  bias=False
#   up_proj:         torch.Size([9728, 2560])  bias=False
#   down_proj:       torch.Size([2560, 9728])  bias=False
#   ln weight shape: torch.Size([2560])
#
# TOKENIZATION
# ------------------------------------------------------------
#   Using PDF (pdftotext): /workspace/literature/2403.00232v1.pdf
#   Sequence length: 250 tokens
#
# INSTRUMENTED FORWARD PASS
# ------------------------------------------------------------
#   Running model forward pass... done.
#   ffn_residual              [250, 2560]  dtype=torch.bfloat16  range=[-1920.0000, 6976.0000]
#   rms_out                   [250, 2560]  dtype=torch.bfloat16  range=[-16.6250, 7.5312]
#   gate_out                  [250, 9728]  dtype=torch.bfloat16  range=[-6.5000, 7.5938]
#   up_out                    [250, 9728]  dtype=torch.bfloat16  range=[-5.7500, 6.4688]
#   down_input                [250, 9728]  dtype=torch.bfloat16  range=[-10.8750, 13.3125]
#   down_out                  [250, 2560]  dtype=torch.bfloat16  range=[-7.8438, 6.4062]
#
# ARCHITECTURE VERIFICATION
# ------------------------------------------------------------
#   SiLU(gate_out) * up_out == down_proj input?
#     0/2432000 BF16 diffs  *** CONFIRMED: act_fn is SiLU, no hidden casts or fused kernels ***
#   down_proj(captured_input) == captured_output?
#     0 diffs  *** CONFIRMED: down_proj is a plain linear, no hidden ops ***
#
# ELEMENT-WISE PRECISION VALIDATION
# ------------------------------------------------------------
#   SiLU GPU torch vs CPU torch:    0/2432000 BF16 diffs
#   SiLU GPU torch vs CPU numpy:    0/2432000 BF16 diffs
#   SiLU CPU torch vs CPU numpy:    0/2432000 BF16 diffs
#   *** All three agree at BF16. Element-wise is safe. ***
#
# RMSNorm FP32 INTERMEDIATE CAPTURE
# ------------------------------------------------------------
#   gpu_sumsq:      [250, 1]  range=[2911.8591, 52600208.0000]
#   gpu_variance:   [250, 1]  range=[1.137445, 20546.957031]
#   gpu_rsqrt:      [250, 1]  range=[0.006976, 0.937637]
#
# SAVING DATA
# ------------------------------------------------------------
#   ffn_chain_data/seq250/model_ffn_residual.bin
#   ffn_chain_data/seq250/model_rms_out.bin
#   ffn_chain_data/seq250/model_gate_out.bin
#   ffn_chain_data/seq250/model_up_out.bin
#   ffn_chain_data/seq250/model_down_input.bin
#   ffn_chain_data/seq250/model_down_out.bin
#   ffn_chain_data/seq250/model_ffn_block_out.bin
#   ffn_chain_data/seq250/model_silu_gate.bin
#   ffn_chain_data/seq250/gpu_rms_sumsq.bin       [250, 1]
#   ffn_chain_data/seq250/gpu_rms_variance.bin     [250, 1]
#   ffn_chain_data/seq250/gpu_rms_rsqrt.bin        [250, 1]
#   ffn_chain_data/seq250/gpu_rms_normed_f32.bin   [250, 2560]
#   ffn_chain_data/seq250/gpu_rms_normed_bf16.bin  [250, 2560]
#   ffn_chain_data/seq250/ln_weight.bin
#   ffn_chain_data/seq250/gate_w.bin  [2560, 9728]
#   ffn_chain_data/seq250/up_w.bin    [2560, 9728]
#   ffn_chain_data/seq250/down_w.bin  [9728, 2560]
#   ffn_chain_data/seq250/meta.json
#
# Phase 1 complete. 8 tensors captured from layer 20.
# Next: python3 ffn_chain_test.py cutlass
#
# ================================================================================
#
# ================================================================================
# PHASE 2: CUTLASS MATMULS + CHAINED GROUND TRUTH
# ================================================================================
#
#   gate_proj: [250,2560]x[2560,9728]... OK
#   gate_proj (FP32): [250,2560]x[2560,9728]... OK
#   up_proj: [250,2560]x[2560,9728]... OK
#   up_proj (FP32): [250,2560]x[2560,9728]... OK
#   SiLU(gate)*up... OK
#   down_proj: [250,9728]x[9728,2560]... OK
#   down_proj (FP32): [250,9728]x[9728,2560]... OK
#   residual add... OK
#
# Phase 2 complete. CUTLASS chain intermediates saved.
# Next: python3 ffn_chain_test.py compare
#
# ================================================================================
#
# ================================================================================
# PHASE 3: CPU EMULATOR + THREE-WAY DIAGNOSTIC
# ================================================================================
#
# Layer 20, seq_len=250, hidden=2560, ffn=9728
# Activation: silu, eps: 1e-06
# Estimated CPU emulator time: ~9339s for 3 matmuls (18678M MAC ops)
#
# MUFU.RSQ: loaded cached tables for A100
# MUFU.EX2: loaded full table for A100 (4.3GB)
# MUFU.RCP: loaded cached table for A100
# GPU detected: A100
# Emulator: A100 bf16→fp32: NFMA=8, neab=1, window=(2,23,1)=26b, round=trunc, denorm=True, MMA=(16, 8, 16), c_order=early, interleaved=False
#
# EMULATOR CHAIN
# ------------------------------------------------------------
#   [1/7] RMSNorm... done (0.9s)
#   [2/7] gate_proj [250,2560]x[2560,9728]... done (10.6s)
#   [3/7] up_proj [250,2560]x[2560,9728]... done (10.1s)
#   [4/7] SiLU... done (0.0s)
#   [5/7] SiLU*up... done (0.1s)
#   [6/7] down_proj [250,9728]x[9728,2560]... done (11.3s)
#   [7/7] residual add... done (0.0s)
#
#   Total: 33.1s
#
#   Saving emulator intermediates...
#   Saved 7 BF16 + 8 raw FP32 tensors to ffn_chain_data/seq250/emu_*.bin
#
# ================================================================================
# THREE-WAY DIAGNOSTIC (every intermediate)
# ================================================================================
#
#   Stage                    Emu vs CUT     Emu vs Model     CUT vs Model
#   ---------------------------------------------------------------------
#   RMSNorm out              N/A            0/640000 ***       N/A
#   gate_proj out         0/2432000 ***    0/2432000 ***    0/2432000 ***
#   up_proj out           0/2432000 ***    0/2432000 ***    0/2432000 ***
#   SiLU(gate)            0/2432000 ***    0/2432000 ***    0/2432000 ***
#   SiLU*up               0/2432000 ***    0/2432000 ***    0/2432000 ***
#   down_proj out          0/640000 *** 181852/640000 (28.41%) 181852/640000 (28.41%)
#   FFN block out          0/640000 *** 78527/640000 (12.27%) 78527/640000 (12.27%)
#
# ================================================================================
# RMSNorm FP32 INTERMEDIATE DIAGNOSTIC
# ================================================================================
#
#   Stage                    FP32 diffs       BF16 diffs    rows affected
#   ----------------------------------------------------------------------
#   sum_of_squares                0/250            0/250            0/250
#   variance                      0/250            0/250            0/250
#   rsqrt                         0/250            0/250            0/250
#   normed_f32                 0/640000         0/640000            0/250
#   normed_bf16                0/640000         0/640000            0/250
#
# ================================================================================
# FP32 RAW ACCUMULATOR DIAGNOSTIC (before BF16 epilogue)
# ================================================================================
#
#   Stage                FP32 diffs   Hidden by BF16   BF16 diffs
#   --------------------------------------------------------------
#   gate_proj             0/2432000                0            0
#   up_proj               0/2432000                0            0
#   down_proj              0/640000                0            0
#
# ================================================================================
# ALL EMULATOR vs CUTLASS COMPARISONS: 0 DIFFS
#   11,008,000 total elements checked across 6 stages
#
# The CPU emulator predicts every BF16 bit of a full FFN block
# at layer 20 of Qwen/Qwen3-4B on 250 real tokens,
# targeting the cutlass kernel family.
# ---- cuBLAS mode ----
# Sequence length override: 250
# Data dir: ffn_chain_data/seq250
# ================================================================================
# PHASE 3: CPU EMULATOR + THREE-WAY DIAGNOSTIC
# ================================================================================
#
# Layer 20, seq_len=250, hidden=2560, ffn=9728
# Activation: silu, eps: 1e-06
# Estimated CPU emulator time: ~9339s for 3 matmuls (18678M MAC ops)
#
# MUFU.RSQ: loaded cached tables for A100
# MUFU.EX2: loaded full table for A100 (4.3GB)
# MUFU.RCP: loaded cached table for A100
# GPU detected: A100
# Emulator: A100 bf16→fp32: NFMA=8, neab=1, window=(2,23,1)=26b, round=trunc, denorm=True, MMA=(16, 8, 16), c_order=early, interleaved=False
#
# EMULATOR CHAIN
# ------------------------------------------------------------
#   [1/7] RMSNorm... done (1.2s)
#   [2/7] gate_proj [250,2560]x[2560,9728]...   [catalog mode] loaded 6 regions across 2 lanes
# done (10.9s)
#   [3/7] up_proj [250,2560]x[2560,9728]... done (8.6s)
#   [4/7] SiLU... done (0.1s)
#   [5/7] SiLU*up... done (0.1s)
#   [6/7] down_proj [250,9728]x[9728,2560]... done (10.0s)
#   [7/7] residual add... done (0.0s)
#
#   Total: 30.8s
#
#   Saving emulator intermediates...
#   Saved 7 BF16 + 8 raw FP32 tensors to ffn_chain_data/seq250/emu_*.bin
#
# ================================================================================
# THREE-WAY DIAGNOSTIC (every intermediate)
# ================================================================================
#
#   Stage                    Emu vs CUT     Emu vs Model     CUT vs Model
#   ---------------------------------------------------------------------
#   RMSNorm out              N/A            0/640000 ***       N/A
#   gate_proj out         0/2432000 ***    0/2432000 ***    0/2432000 ***
#   up_proj out           0/2432000 ***    0/2432000 ***    0/2432000 ***
#   SiLU(gate)            0/2432000 ***    0/2432000 ***    0/2432000 ***
#   SiLU*up               0/2432000 ***    0/2432000 ***    0/2432000 ***
#   down_proj out      181852/640000 (28.41%)     0/640000 *** 181852/640000 (28.41%)
#   FFN block out      78527/640000 (12.27%)     0/640000 *** 78527/640000 (12.27%)
#
# ================================================================================
# RMSNorm FP32 INTERMEDIATE DIAGNOSTIC
# ================================================================================
#
#   Stage                    FP32 diffs       BF16 diffs    rows affected
#   ----------------------------------------------------------------------
#   sum_of_squares                0/250            0/250            0/250
#   variance                      0/250            0/250            0/250
#   rsqrt                         0/250            0/250            0/250
#   normed_f32                 0/640000         0/640000            0/250
#   normed_bf16                0/640000         0/640000            0/250
#
# ================================================================================
# FP32 RAW ACCUMULATOR DIAGNOSTIC (before BF16 epilogue)
# ================================================================================
#
#   Skipped: this diagnostic compares the emulator's raw FP32 output
#   against CUTLASS's FP32 accumulator. In cuBLAS target mode, all
#   recipes BF16-round their output (because cuBLAS rounds to BF16 at
#   partition boundaries), so the emulator's 'FP32' output is BF16
#   precision stored in an FP32 container.
#
# ================================================================================
#
# ================================================================================
# ALL EMULATOR vs MODEL COMPARISONS: 0 DIFFS
#   11,648,000 total elements checked across 7 stages
#
# The CPU emulator predicts every BF16 bit of a full FFN block
# at layer 20 of Qwen/Qwen3-4B on 250 real tokens,
# targeting the model kernel family.
# ================ seq=1000 ================
# Sequence length override: 1000
# Data dir: ffn_chain_data/seq1000
# ================================================================================
# PHASE 1: INSTRUMENTED MODEL FORWARD PASS
# ================================================================================
#
# Loading Qwen/Qwen3-4B...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|██████████| 398/398 [00:02<00:00, 175.77it/s]
# Loaded. 36 layers, targeting layer 20.
#
# ARCHITECTURE INSPECTION
# ------------------------------------------------------------
#   model.config.hidden_size:       2560
#   model.config.intermediate_size:  9728
#   model.config.hidden_act:         silu
#   model.config.rms_norm_eps:       1e-06
#   LayerNorm type:  Qwen3RMSNorm
#   MLP type:        Qwen3MLP
#   act_fn type:     SiLUActivation
#   gate_proj:       torch.Size([9728, 2560])  bias=False
#   up_proj:         torch.Size([9728, 2560])  bias=False
#   down_proj:       torch.Size([2560, 9728])  bias=False
#   ln weight shape: torch.Size([2560])
#
# TOKENIZATION
# ------------------------------------------------------------
#   Using PDF (pdftotext): /workspace/literature/2403.00232v1.pdf
#   Sequence length: 1000 tokens
#
# INSTRUMENTED FORWARD PASS
# ------------------------------------------------------------
#   Running model forward pass... done.
#   ffn_residual             [1000, 2560]  dtype=torch.bfloat16  range=[-1920.0000, 6976.0000]
#   rms_out                  [1000, 2560]  dtype=torch.bfloat16  range=[-16.6250, 7.5312]
#   gate_out                 [1000, 9728]  dtype=torch.bfloat16  range=[-6.7812, 8.3125]
#   up_out                   [1000, 9728]  dtype=torch.bfloat16  range=[-5.7812, 6.4375]
#   down_input               [1000, 9728]  dtype=torch.bfloat16  range=[-15.5625, 13.6875]
#   down_out                 [1000, 2560]  dtype=torch.bfloat16  range=[-7.9062, 6.3750]
#
# ARCHITECTURE VERIFICATION
# ------------------------------------------------------------
#   SiLU(gate_out) * up_out == down_proj input?
#     0/9728000 BF16 diffs  *** CONFIRMED: act_fn is SiLU, no hidden casts or fused kernels ***
#   down_proj(captured_input) == captured_output?
#     0 diffs  *** CONFIRMED: down_proj is a plain linear, no hidden ops ***
#
# ELEMENT-WISE PRECISION VALIDATION
# ------------------------------------------------------------
#   SiLU GPU torch vs CPU torch:    0/9728000 BF16 diffs
#   SiLU GPU torch vs CPU numpy:    0/9728000 BF16 diffs
#   SiLU CPU torch vs CPU numpy:    0/9728000 BF16 diffs
#   *** All three agree at BF16. Element-wise is safe. ***
#
# RMSNorm FP32 INTERMEDIATE CAPTURE
# ------------------------------------------------------------
#   gpu_sumsq:      [1000, 1]  range=[2903.2676, 52597592.0000]
#   gpu_variance:   [1000, 1]  range=[1.134089, 20545.935547]
#   gpu_rsqrt:      [1000, 1]  range=[0.006976, 0.939023]
#
# SAVING DATA
# ------------------------------------------------------------
#   ffn_chain_data/seq1000/model_ffn_residual.bin
#   ffn_chain_data/seq1000/model_rms_out.bin
#   ffn_chain_data/seq1000/model_gate_out.bin
#   ffn_chain_data/seq1000/model_up_out.bin
#   ffn_chain_data/seq1000/model_down_input.bin
#   ffn_chain_data/seq1000/model_down_out.bin
#   ffn_chain_data/seq1000/model_ffn_block_out.bin
#   ffn_chain_data/seq1000/model_silu_gate.bin
#   ffn_chain_data/seq1000/gpu_rms_sumsq.bin       [1000, 1]
#   ffn_chain_data/seq1000/gpu_rms_variance.bin     [1000, 1]
#   ffn_chain_data/seq1000/gpu_rms_rsqrt.bin        [1000, 1]
#   ffn_chain_data/seq1000/gpu_rms_normed_f32.bin   [1000, 2560]
#   ffn_chain_data/seq1000/gpu_rms_normed_bf16.bin  [1000, 2560]
#   ffn_chain_data/seq1000/ln_weight.bin
#   ffn_chain_data/seq1000/gate_w.bin  [2560, 9728]
#   ffn_chain_data/seq1000/up_w.bin    [2560, 9728]
#   ffn_chain_data/seq1000/down_w.bin  [9728, 2560]
#   ffn_chain_data/seq1000/meta.json
#
# Phase 1 complete. 8 tensors captured from layer 20.
# Next: python3 ffn_chain_test.py cutlass
#
# ================================================================================
#
# ================================================================================
# PHASE 2: CUTLASS MATMULS + CHAINED GROUND TRUTH
# ================================================================================
#
#   gate_proj: [1000,2560]x[2560,9728]... OK
#   gate_proj (FP32): [1000,2560]x[2560,9728]... OK
#   up_proj: [1000,2560]x[2560,9728]... OK
#   up_proj (FP32): [1000,2560]x[2560,9728]... OK
#   SiLU(gate)*up... OK
#   down_proj: [1000,9728]x[9728,2560]... OK
#   down_proj (FP32): [1000,9728]x[9728,2560]... OK
#   residual add... OK
#
# Phase 2 complete. CUTLASS chain intermediates saved.
# Next: python3 ffn_chain_test.py compare
#
# ================================================================================
#
# ================================================================================
# PHASE 3: CPU EMULATOR + THREE-WAY DIAGNOSTIC
# ================================================================================
#
# Layer 20, seq_len=1000, hidden=2560, ffn=9728
# Activation: silu, eps: 1e-06
# Estimated CPU emulator time: ~37356s for 3 matmuls (74711M MAC ops)
#
# MUFU.RSQ: loaded cached tables for A100
# MUFU.EX2: loaded full table for A100 (4.3GB)
# MUFU.RCP: loaded cached table for A100
# GPU detected: A100
# Emulator: A100 bf16→fp32: NFMA=8, neab=1, window=(2,23,1)=26b, round=trunc, denorm=True, MMA=(16, 8, 16), c_order=early, interleaved=False
#
# EMULATOR CHAIN
# ------------------------------------------------------------
#   [1/7] RMSNorm... done (3.2s)
#   [2/7] gate_proj [1000,2560]x[2560,9728]... done (42.7s)
#   [3/7] up_proj [1000,2560]x[2560,9728]... done (37.5s)
#   [4/7] SiLU... done (0.4s)
#   [5/7] SiLU*up... done (0.3s)
#   [6/7] down_proj [1000,9728]x[9728,2560]... done (45.8s)
#   [7/7] residual add... done (0.0s)
#
#   Total: 129.9s
#
#   Saving emulator intermediates...
#   Saved 7 BF16 + 8 raw FP32 tensors to ffn_chain_data/seq1000/emu_*.bin
#
# ================================================================================
# THREE-WAY DIAGNOSTIC (every intermediate)
# ================================================================================
#
#   Stage                    Emu vs CUT     Emu vs Model     CUT vs Model
#   ---------------------------------------------------------------------
#   RMSNorm out              N/A           0/2560000 ***       N/A
#   gate_proj out         0/9728000 ***    0/9728000 ***    0/9728000 ***
#   up_proj out           0/9728000 ***    0/9728000 ***    0/9728000 ***
#   SiLU(gate)            0/9728000 ***    0/9728000 ***    0/9728000 ***
#   SiLU*up               0/9728000 ***    0/9728000 ***    0/9728000 ***
#   down_proj out         0/2560000 *** 1099970/2560000 (42.97%) 1099970/2560000 (42.97%)
#   FFN block out         0/2560000 *** 504216/2560000 (19.70%) 504216/2560000 (19.70%)
#
# ================================================================================
# RMSNorm FP32 INTERMEDIATE DIAGNOSTIC
# ================================================================================
#
#   Stage                    FP32 diffs       BF16 diffs    rows affected
#   ----------------------------------------------------------------------
#   sum_of_squares               0/1000           0/1000           0/1000
#   variance                     0/1000           0/1000           0/1000
#   rsqrt                        0/1000           0/1000           0/1000
#   normed_f32                0/2560000        0/2560000           0/1000
#   normed_bf16               0/2560000        0/2560000           0/1000
#
# ================================================================================
# FP32 RAW ACCUMULATOR DIAGNOSTIC (before BF16 epilogue)
# ================================================================================
#
#   Stage                FP32 diffs   Hidden by BF16   BF16 diffs
#   --------------------------------------------------------------
#   gate_proj             0/9728000                0            0
#   up_proj               0/9728000                0            0
#   down_proj             0/2560000                0            0
#
# ================================================================================
# ALL EMULATOR vs CUTLASS COMPARISONS: 0 DIFFS
#   44,032,000 total elements checked across 6 stages
#
# The CPU emulator predicts every BF16 bit of a full FFN block
# at layer 20 of Qwen/Qwen3-4B on 1000 real tokens,
# targeting the cutlass kernel family.
# ---- cuBLAS mode ----
# Sequence length override: 1000
# Data dir: ffn_chain_data/seq1000
# ================================================================================
# PHASE 3: CPU EMULATOR + THREE-WAY DIAGNOSTIC
# ================================================================================
#
# Layer 20, seq_len=1000, hidden=2560, ffn=9728
# Activation: silu, eps: 1e-06
# Estimated CPU emulator time: ~37356s for 3 matmuls (74711M MAC ops)
#
# MUFU.RSQ: loaded cached tables for A100
# MUFU.EX2: loaded full table for A100 (4.3GB)
# MUFU.RCP: loaded cached table for A100
# GPU detected: A100
# Emulator: A100 bf16→fp32: NFMA=8, neab=1, window=(2,23,1)=26b, round=trunc, denorm=True, MMA=(16, 8, 16), c_order=early, interleaved=False
#
# EMULATOR CHAIN
# ------------------------------------------------------------
#   [1/7] RMSNorm... done (3.4s)
#   [2/7] gate_proj [1000,2560]x[2560,9728]...   [catalog mode] loaded 6 regions across 2 lanes
# done (44.7s)
#   [3/7] up_proj [1000,2560]x[2560,9728]... done (41.8s)
#   [4/7] SiLU... done (0.4s)
#   [5/7] SiLU*up... done (0.2s)
#   [6/7] down_proj [1000,9728]x[9728,2560]... done (37.6s)
#   [7/7] residual add... done (0.1s)
#
#   Total: 128.2s
#
#   Saving emulator intermediates...
#   Saved 7 BF16 + 8 raw FP32 tensors to ffn_chain_data/seq1000/emu_*.bin
#
# ================================================================================
# THREE-WAY DIAGNOSTIC (every intermediate)
# ================================================================================
#
#   Stage                    Emu vs CUT     Emu vs Model     CUT vs Model
#   ---------------------------------------------------------------------
#   RMSNorm out              N/A           0/2560000 ***       N/A
#   gate_proj out         0/9728000 ***    0/9728000 ***    0/9728000 ***
#   up_proj out           0/9728000 ***    0/9728000 ***    0/9728000 ***
#   SiLU(gate)            0/9728000 ***    0/9728000 ***    0/9728000 ***
#   SiLU*up               0/9728000 ***    0/9728000 ***    0/9728000 ***
#   down_proj out      1099970/2560000 (42.97%)    0/2560000 *** 1099970/2560000 (42.97%)
#   FFN block out      504216/2560000 (19.70%)    0/2560000 *** 504216/2560000 (19.70%)
#
# ================================================================================
# RMSNorm FP32 INTERMEDIATE DIAGNOSTIC
# ================================================================================
#
#   Stage                    FP32 diffs       BF16 diffs    rows affected
#   ----------------------------------------------------------------------
#   sum_of_squares               0/1000           0/1000           0/1000
#   variance                     0/1000           0/1000           0/1000
#   rsqrt                        0/1000           0/1000           0/1000
#   normed_f32                0/2560000        0/2560000           0/1000
#   normed_bf16               0/2560000        0/2560000           0/1000
#
# ================================================================================
# FP32 RAW ACCUMULATOR DIAGNOSTIC (before BF16 epilogue)
# ================================================================================
#
#   Skipped: this diagnostic compares the emulator's raw FP32 output
#   against CUTLASS's FP32 accumulator. In cuBLAS target mode, all
#   recipes BF16-round their output (because cuBLAS rounds to BF16 at
#   partition boundaries), so the emulator's 'FP32' output is BF16
#   precision stored in an FP32 container.
#
# ================================================================================
#
# ================================================================================
# ALL EMULATOR vs MODEL COMPARISONS: 0 DIFFS
#   46,592,000 total elements checked across 7 stages
#
# The CPU emulator predicts every BF16 bit of a full FFN block
# at layer 20 of Qwen/Qwen3-4B on 1000 real tokens,
# targeting the model kernel family.
# ================ seq=4000 ================
# Sequence length override: 4000
# Data dir: ffn_chain_data/seq4000
# ================================================================================
# PHASE 1: INSTRUMENTED MODEL FORWARD PASS
# ================================================================================
#
# Loading Qwen/Qwen3-4B...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|██████████| 398/398 [00:02<00:00, 136.73it/s]
# Loaded. 36 layers, targeting layer 20.
#
# ARCHITECTURE INSPECTION
# ------------------------------------------------------------
#   model.config.hidden_size:       2560
#   model.config.intermediate_size:  9728
#   model.config.hidden_act:         silu
#   model.config.rms_norm_eps:       1e-06
#   LayerNorm type:  Qwen3RMSNorm
#   MLP type:        Qwen3MLP
#   act_fn type:     SiLUActivation
#   gate_proj:       torch.Size([9728, 2560])  bias=False
#   up_proj:         torch.Size([9728, 2560])  bias=False
#   down_proj:       torch.Size([2560, 9728])  bias=False
#   ln weight shape: torch.Size([2560])
#
# TOKENIZATION
# ------------------------------------------------------------
#   Using PDF (pdftotext): /workspace/literature/2403.00232v1.pdf
#   Sequence length: 4000 tokens
#
# INSTRUMENTED FORWARD PASS
# ------------------------------------------------------------
#   Running model forward pass... done.
#   ffn_residual             [4000, 2560]  dtype=torch.bfloat16  range=[-1920.0000, 7520.0000]
#   rms_out                  [4000, 2560]  dtype=torch.bfloat16  range=[-16.6250, 7.5938]
#   gate_out                 [4000, 9728]  dtype=torch.bfloat16  range=[-6.9688, 8.3750]
#   up_out                   [4000, 9728]  dtype=torch.bfloat16  range=[-6.9062, 6.4688]
#   down_input               [4000, 9728]  dtype=torch.bfloat16  range=[-15.5625, 15.3750]
#   down_out                 [4000, 2560]  dtype=torch.bfloat16  range=[-11.4375, 6.4375]
#
# ARCHITECTURE VERIFICATION
# ------------------------------------------------------------
#   SiLU(gate_out) * up_out == down_proj input?
#     0/38912000 BF16 diffs  *** CONFIRMED: act_fn is SiLU, no hidden casts or fused kernels ***
#   down_proj(captured_input) == captured_output?
#     0 diffs  *** CONFIRMED: down_proj is a plain linear, no hidden ops ***
#
# ELEMENT-WISE PRECISION VALIDATION
# ------------------------------------------------------------
#   SiLU GPU torch vs CPU torch:    0/38912000 BF16 diffs
#   SiLU GPU torch vs CPU numpy:    0/38912000 BF16 diffs
#   SiLU CPU torch vs CPU numpy:    0/38912000 BF16 diffs
#   *** All three agree at BF16. Element-wise is safe. ***
#
# RMSNorm FP32 INTERMEDIATE CAPTURE
# ------------------------------------------------------------
#   gpu_sumsq:      [4000, 1]  range=[2533.1794, 58107772.0000]
#   gpu_variance:   [4000, 1]  range=[0.989523, 22698.349609]
#   gpu_rsqrt:      [4000, 1]  range=[0.006637, 1.005279]
#
# SAVING DATA
# ------------------------------------------------------------
#   ffn_chain_data/seq4000/model_ffn_residual.bin
#   ffn_chain_data/seq4000/model_rms_out.bin
#   ffn_chain_data/seq4000/model_gate_out.bin
#   ffn_chain_data/seq4000/model_up_out.bin
#   ffn_chain_data/seq4000/model_down_input.bin
#   ffn_chain_data/seq4000/model_down_out.bin
#   ffn_chain_data/seq4000/model_ffn_block_out.bin
#   ffn_chain_data/seq4000/model_silu_gate.bin
#   ffn_chain_data/seq4000/gpu_rms_sumsq.bin       [4000, 1]
#   ffn_chain_data/seq4000/gpu_rms_variance.bin     [4000, 1]
#   ffn_chain_data/seq4000/gpu_rms_rsqrt.bin        [4000, 1]
#   ffn_chain_data/seq4000/gpu_rms_normed_f32.bin   [4000, 2560]
#   ffn_chain_data/seq4000/gpu_rms_normed_bf16.bin  [4000, 2560]
#   ffn_chain_data/seq4000/ln_weight.bin
#   ffn_chain_data/seq4000/gate_w.bin  [2560, 9728]
#   ffn_chain_data/seq4000/up_w.bin    [2560, 9728]
#   ffn_chain_data/seq4000/down_w.bin  [9728, 2560]
#   ffn_chain_data/seq4000/meta.json
#
# Phase 1 complete. 8 tensors captured from layer 20.
# Next: python3 ffn_chain_test.py cutlass
#
# ================================================================================
#
# ================================================================================
# PHASE 2: CUTLASS MATMULS + CHAINED GROUND TRUTH
# ================================================================================
#
#   gate_proj: [4000,2560]x[2560,9728]... OK
#   gate_proj (FP32): [4000,2560]x[2560,9728]... OK
#   up_proj: [4000,2560]x[2560,9728]... OK
#   up_proj (FP32): [4000,2560]x[2560,9728]... OK
#   SiLU(gate)*up... OK
#   down_proj: [4000,9728]x[9728,2560]... OK
#   down_proj (FP32): [4000,9728]x[9728,2560]... OK
#   residual add... OK
#
# Phase 2 complete. CUTLASS chain intermediates saved.
# Next: python3 ffn_chain_test.py compare
#
# ================================================================================
#
# ================================================================================
# PHASE 3: CPU EMULATOR + THREE-WAY DIAGNOSTIC
# ================================================================================
#
# Layer 20, seq_len=4000, hidden=2560, ffn=9728
# Activation: silu, eps: 1e-06
# Estimated CPU emulator time: ~149422s for 3 matmuls (298844M MAC ops)
#
# MUFU.RSQ: loaded cached tables for A100
# MUFU.EX2: loaded full table for A100 (4.3GB)
# MUFU.RCP: loaded cached table for A100
# GPU detected: A100
# Emulator: A100 bf16→fp32: NFMA=8, neab=1, window=(2,23,1)=26b, round=trunc, denorm=True, MMA=(16, 8, 16), c_order=early, interleaved=False
#
# EMULATOR CHAIN
# ------------------------------------------------------------
#   [1/7] RMSNorm... done (13.9s)
#   [2/7] gate_proj [4000,2560]x[2560,9728]... done (157.7s)
#   [3/7] up_proj [4000,2560]x[2560,9728]... done (134.5s)
#   [4/7] SiLU... done (0.7s)
#   [5/7] SiLU*up... done (0.6s)
#   [6/7] down_proj [4000,9728]x[9728,2560]... done (146.0s)
#   [7/7] residual add... done (0.4s)
#
#   Total: 453.8s
#
#   Saving emulator intermediates...
#   Saved 7 BF16 + 8 raw FP32 tensors to ffn_chain_data/seq4000/emu_*.bin
#
# ================================================================================
# THREE-WAY DIAGNOSTIC (every intermediate)
# ================================================================================
#
#   Stage                    Emu vs CUT     Emu vs Model     CUT vs Model
#   ---------------------------------------------------------------------
#   RMSNorm out              N/A          0/10240000 ***       N/A
#   gate_proj out        0/38912000 ***   0/38912000 ***   0/38912000 ***
#   up_proj out          0/38912000 ***   0/38912000 ***   0/38912000 ***
#   SiLU(gate)           0/38912000 ***   0/38912000 ***   0/38912000 ***
#   SiLU*up              0/38912000 ***   0/38912000 ***   0/38912000 ***
#   down_proj out        0/10240000 ***   0/10240000 ***   0/10240000 ***
#   FFN block out        0/10240000 ***   0/10240000 ***   0/10240000 ***
#
# ================================================================================
# RMSNorm FP32 INTERMEDIATE DIAGNOSTIC
# ================================================================================
#
#   Stage                    FP32 diffs       BF16 diffs    rows affected
#   ----------------------------------------------------------------------
#   sum_of_squares               0/4000           0/4000           0/4000
#   variance                     0/4000           0/4000           0/4000
#   rsqrt                        0/4000           0/4000           0/4000
#   normed_f32               0/10240000       0/10240000           0/4000
#   normed_bf16              0/10240000       0/10240000           0/4000
#
# ================================================================================
# FP32 RAW ACCUMULATOR DIAGNOSTIC (before BF16 epilogue)
# ================================================================================
#
#   Stage                FP32 diffs   Hidden by BF16   BF16 diffs
#   --------------------------------------------------------------
#   gate_proj            0/38912000                0            0
#   up_proj              0/38912000                0            0
#   down_proj            0/10240000                0            0
#
# ================================================================================
# ALL EMULATOR vs CUTLASS COMPARISONS: 0 DIFFS
#   176,128,000 total elements checked across 6 stages
#
# The CPU emulator predicts every BF16 bit of a full FFN block
# at layer 20 of Qwen/Qwen3-4B on 4000 real tokens,
# targeting the cutlass kernel family.
# ---- cuBLAS mode ----
# Sequence length override: 4000
# Data dir: ffn_chain_data/seq4000
# ================================================================================
# PHASE 3: CPU EMULATOR + THREE-WAY DIAGNOSTIC
# ================================================================================
#
# Layer 20, seq_len=4000, hidden=2560, ffn=9728
# Activation: silu, eps: 1e-06
# Estimated CPU emulator time: ~149422s for 3 matmuls (298844M MAC ops)
#
# MUFU.RSQ: loaded cached tables for A100
# MUFU.EX2: loaded full table for A100 (4.3GB)
# MUFU.RCP: loaded cached table for A100
# GPU detected: A100
# Emulator: A100 bf16→fp32: NFMA=8, neab=1, window=(2,23,1)=26b, round=trunc, denorm=True, MMA=(16, 8, 16), c_order=early, interleaved=False
#
# EMULATOR CHAIN
# ------------------------------------------------------------
#   [1/7] RMSNorm... done (14.5s)
#   [2/7] gate_proj [4000,2560]x[2560,9728]...   [catalog mode] loaded 6 regions across 2 lanes
# done (119.2s)
#   [3/7] up_proj [4000,2560]x[2560,9728]... done (132.5s)
#   [4/7] SiLU... done (0.6s)
#   [5/7] SiLU*up... done (0.6s)
#   [6/7] down_proj [4000,9728]x[9728,2560]... done (164.3s)
#   [7/7] residual add... done (0.2s)
#
#   Total: 431.9s
#
#   Saving emulator intermediates...
#   Saved 7 BF16 + 8 raw FP32 tensors to ffn_chain_data/seq4000/emu_*.bin
#
# ================================================================================
# THREE-WAY DIAGNOSTIC (every intermediate)
# ================================================================================
#
#   Stage                    Emu vs CUT     Emu vs Model     CUT vs Model
#   ---------------------------------------------------------------------
#   RMSNorm out              N/A          0/10240000 ***       N/A
#   gate_proj out        0/38912000 ***   0/38912000 ***   0/38912000 ***
#   up_proj out          0/38912000 ***   0/38912000 ***   0/38912000 ***
#   SiLU(gate)           0/38912000 ***   0/38912000 ***   0/38912000 ***
#   SiLU*up              0/38912000 ***   0/38912000 ***   0/38912000 ***
#   down_proj out        0/10240000 ***   0/10240000 ***   0/10240000 ***
#   FFN block out        0/10240000 ***   0/10240000 ***   0/10240000 ***
#
# ================================================================================
# RMSNorm FP32 INTERMEDIATE DIAGNOSTIC
# ================================================================================
#
#   Stage                    FP32 diffs       BF16 diffs    rows affected
#   ----------------------------------------------------------------------
#   sum_of_squares               0/4000           0/4000           0/4000
#   variance                     0/4000           0/4000           0/4000
#   rsqrt                        0/4000           0/4000           0/4000
#   normed_f32               0/10240000       0/10240000           0/4000
#   normed_bf16              0/10240000       0/10240000           0/4000
#
# ================================================================================
# FP32 RAW ACCUMULATOR DIAGNOSTIC (before BF16 epilogue)
# ================================================================================
#
#   Skipped: this diagnostic compares the emulator's raw FP32 output
#   against CUTLASS's FP32 accumulator. In cuBLAS target mode, all
#   recipes BF16-round their output (because cuBLAS rounds to BF16 at
#   partition boundaries), so the emulator's 'FP32' output is BF16
#   precision stored in an FP32 container.
#
# ================================================================================
#
# ================================================================================
# ALL EMULATOR vs MODEL COMPARISONS: 0 DIFFS
#   186,368,000 total elements checked across 7 stages
#
# The CPU emulator predicts every BF16 bit of a full FFN block
# at layer 20 of Qwen/Qwen3-4B on 4000 real tokens,
# targeting the model kernel family.
