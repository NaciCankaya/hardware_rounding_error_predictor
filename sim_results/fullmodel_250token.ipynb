# %%
python3 -u emulate_forward.py forward_capture_500
# Out:
# ...
# FULL FORWARD PASS EMULATION
#   capture: forward_capture
#   model:   Qwen/Qwen3-4B
#   seq_len: 250  layers: 36  hidden: 2560
# ...
#
# MUFU.RSQ: loaded cached tables for A100
# MUFU.EX2: loaded full table for A100 (4.3GB)
# MUFU.RCP: loaded cached table for A100
# Emulating A100  —  A100 bf16→fp32: NFMA=8, neab=1, window=(2,23,1)=26b, round=trunc, denorm=True, MMA=(16, 8, 16), c_order=early, interleaved=False
#
# Loading Qwen/Qwen3-4B weights on CPU (this takes a moment)...
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|██████████████████████| 398/398 [00:00<00:00, 5169.27it/s]
# ...
# done.
#
# Loading RoPE cos/sin...
#   cos/sin shape: (250, 128)
#
# LAYER EMULATION
# ------------------------------------------------------------
#    Layer          Attn           FFN      Time
#   ----------------------------------------------
#
#   Layer  0 attn:
#   FA2 attention core...
#     Head 0/32...
#     Head 8/32 (1s, ETA 2s)...
#     Head 16/32 (1s, ETA 1s)...
# ...

# %%
cd hardware_rounding_error_predictor
